# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset/data.csv', index_col=0)
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.drop(['ID','Photo','Flag','Club Logo','International Reputation', 'Weak Foot',
        'Work Rate', 'Body Type', 'Real Face','Contract Valid Until'],
       axis=1, inplace=True)

# %%
df.drop(['Height', 'Weight'],axis=1, inplace=True)

# %%
df.drop(['Preferred Foot'],axis=1, inplace=True)

# %% [markdown]
# 데이터 없는 행 삭제

# %%
nan_data=df.iloc[13236:13284,:]
nan_data.index
df.drop(nan_data.index,inplace = True)

# %% [markdown]
# Club 없는 선수들도 삭제

# %%
df.Club.isnull().sum()
# Out:
# 241

# %%
# club nan 행 탐색
df.Club.fillna('non_club', inplace = True)
non_club_s=df[df.Club =='non_club'].index
df.drop(non_club_s,inplace = True)

# %%
df.Joined.isnull().sum()
# Out:
# 1264

# %%
df['Jersey Number'].isnull().sum()
# Out:
# 0

# %% [markdown]
# value=0인 선수도 삭제(은퇴 직전?)

# %%
value_zero=df[df.Value==0].index
df.drop(value_zero, inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
# Potential            0
#                   ...
# GKHandling           0
# GKKicking            0
# GKPositioning        0
# GKReflexes           0
# Release Clause    1275
# Length: 75, dtype: int64

# %%
star=df[df['Position'=='GK'][['Name','Wage','Jersey Number'
                                                       ,'Position','Overall','LS', 'GKDiving']]
star.head(30)
# Out:
#               Name   Wage  Jersey Number Position  Overall    LS  GKDiving
# 0         L. Messi  €565K           10.0       RF       94  88+2       6.0
# 2        Neymar Jr  €290K           10.0       LW       92  84+3       9.0
# 5        E. Hazard  €340K           10.0       LF       91  83+3      11.0
# 6        L. Modrić  €420K           10.0      RCM       91  77+3      13.0
# 12        D. Godín  €125K           10.0       CB       90  64+3       6.0
# 23       S. Agüero  €300K           10.0       ST       89  86+3      13.0
# 25       K. Mbappé  €100K           10.0       RM       88  85+3      13.0
# 26        M. Salah  €255K           10.0       RM       88  83+3      14.0
# 28    J. Rodríguez  €315K           10.0      LAM       88  80+3      15.0
# 29      L. Insigne  €165K           10.0       LW       88  78+3       8.0
# 31      C. Eriksen  €205K           10.0      CAM       88  79+3       9.0
# ...

# %%
Jersey=df[(df['Jersey Number']>11)&(df['Jersey Number']<99)][['Name','Wage','Jersey Number'
                                                       ,'Position','Overall','LS', 'GKDiving']]

# %%
Jersey.head(30)
# Out:
#                    Name   Wage  Jersey Number Position  Overall    LS  \
# 8          Sergio Ramos  €380K           15.0      RCB       91  73+3
# 13          David Silva  €285K           21.0      LCM       90  77+3
# 14             N. Kanté  €225K           13.0      LDM       89  72+3
# 15            P. Dybala  €205K           21.0       LF       89  83+3
# 18        M. ter Stegen  €240K           22.0       GK       89   NaN
# 21            E. Cavani  €200K           21.0       LS       89  85+3
# 27             Casemiro  €285K           14.0      CDM       88  72+3
# 30                 Isco  €315K           22.0       LW       88  76+3
# 33        P. Aubameyang  €265K           14.0       LM       88  84+3
# 35              Marcelo  €285K           12.0       LB       88  80+3
# 42            S. Umtiti  €205K           23.0       CB       87  70+3
# 44         K. Koulibaly  €115K           26.0      LCB       87  52+3
# ...

# %%
Jersey['Jersey Number'].describe()
# Out:
# count    11694.000000
# mean        26.340944
# std         14.363045
# min         12.000000
# 25%         18.000000
# 50%         23.000000
# 75%         30.000000
# max         98.000000
# Name: Jersey Number, dtype: float64

# %%
Jersey['Jersey Number'].unique()
# Out:
# array([15., 21., 13., 22., 14., 12., 23., 26., 17., 18., 19., 31., 25.,
#        37., 30., 44., 29., 24., 20., 16., 33., 28., 27., 77., 47., 38.,
#        40., 92., 36., 87., 34., 32., 83., 70., 35., 89., 56., 57., 91.,
#        86., 45., 63., 39., 43., 42., 93., 72., 71., 88., 55., 80., 50.,
#        66., 60., 73., 67., 74., 69., 76., 41., 90., 46., 75., 79., 62.,
#        81., 61., 49., 95., 53., 96., 97., 68., 98., 94., 58., 78., 48.,
#        52., 54., 84., 82., 65., 64., 51., 59., 85.])

# %%
df['Jersey Number'].unique()
# Out:
# array([10.,  7.,  1.,  9., 15.,  8., 21., 13., 22.,  5.,  3., 14., 12.,
#        11.,  2., 23., 26.,  6., 17., 18.,  4., 19., 31., 25., 37., 30.,
#        44., 29., 24., 20., 16., 33., 28., 27., 77., 47., 38., 40., 92.,
#        36., 87., 34., 32., 83., 70., 35., 89., 56., 99., 57., 91., 86.,
#        45., 63., 39., 43., 42., 93., 72., 71., 88., 55., 80., 50., 66.,
#        60., 73., 67., 74., 69., 76., 41., 90., 46., 75., 79., 62., 81.,
#        61., 49., 95., 53., 96., 97., 68., 98., 94., 58., 78., nan, 48.,
#        52., 54., 84., 82., 65., 64., 51., 59., 85.])

# %%
df1=df[['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
       'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']]
